# %% [markdown]
# E.T.L del Dataset Movies

# %%
#Importo las librerias a utilizar.
import pandas as pd
import numpy as np
import json

# %%
# Utilizo la libreria Pandas para leer el archivo csv.
data = pd.read_csv('../Datasets/movies_dataset.csv', sep=',', encoding='utf-8', low_memory=False)

# %% [markdown]
# Comiezo a examinar el Dataset, evaluando los pasos a seguir.

# %%
# Visualizo las primeras 5 filas del Dataset movies
data.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# 2                                   NaN  15602  tt0113228                en
# 3                                   NaN  31357  tt0114885                en
# 4                                   NaN  11862  tt0113041                en
#
#                 original_title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview  ... release_date  \
# 0  Led by Woody, Andy's toys live happily in his ...  ...   1995-10-30
# 1  When siblings Judy and Peter discover an encha...  ...   1995-12-15
# 2  A family wedding reignites the ancient feud be...  ...   1995-12-22
# 3  Cheated on, mistreated and stepped on, the wom...  ...   1995-12-22
# 4  Just when George Banks has recovered from his ...  ...   1995-02-10
#
#        revenue runtime                                   spoken_languages  \
# 0  373554033.0    81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1  262797249.0   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2          0.0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3   81452156.0   127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4   76578911.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#      status                                            tagline  \
# 0  Released                                                NaN
# 1  Released          Roll the dice and unleash the excitement!
# 2  Released  Still Yelling. Still Fighting. Still Ready for...
# 3  Released  Friends are the people who let you be yourself...
# 4  Released  Just When His World Is Back To Normal... He's ...
#
#                          title  video vote_average vote_count
# 0                    Toy Story  False          7.7     5415.0
# 1                      Jumanji  False          6.9     2413.0
# 2             Grumpier Old Men  False          6.5       92.0
# 3            Waiting to Exhale  False          6.1       34.0
# 4  Father of the Bride Part II  False          5.7      173.0
#
# [5 rows x 24 columns]

# %%
# Solicito la cantidad de filas y columnas del Dataset movies (filas: 45466, columnas: 24)
data.shape
# Out:
# (45466, 24)

# %% [markdown]
# ---

# %% [markdown]
# Comienzo a trabajar el Dataset.

# %%
# Elimino las columnas que no son de mi interes para el analisis.
data.drop(['video', 'imdb_id', 'adult', 'original_title', 'poster_path', 'homepage', 'tagline'], axis=1, inplace=True)

# %%
#Solicito nuevamente la cantidad de filas y columnas para verificar que se hayan eliminado. (Filas: 45466, Columnas:18)
data.shape
# Out:
# (45466, 17)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   belongs_to_collection  4494 non-null   object
#  1   budget                 45466 non-null  object
#  2   genres                 45466 non-null  object
#  3   id                     45466 non-null  object
#  4   original_language      45455 non-null  object
#  5   overview               44512 non-null  object
#  6   popularity             45461 non-null  object
#  7   production_companies   45463 non-null  object
#  8   production_countries   45463 non-null  object
#  9   release_date           45379 non-null  object
#  10  revenue                45460 non-null  float64
#  11  runtime                45203 non-null  float64
#  12  spoken_languages       45460 non-null  object
#  13  status                 45379 non-null  object
#  14  title                  45460 non-null  object
#  15  vote_average           45460 non-null  float64
#  16  vote_count             45460 non-null  float64
# dtypes: float64(4), object(13)
# memory usage: 5.9+ MB

# %% [markdown]
# ----

# %% [markdown]
# Creo una funcion para visualizar facilmente todos los valores nulos del Dataset.

# %%
# Valores nulos en el dataset
def have_nan(df):
    for col in df.columns:
        if df[col].isna().values.any():
            print(col, df[col].isna().values.sum())

have_nan(data)
# Out:
# belongs_to_collection 40972
# original_language 11
# overview 954
# popularity 5
# production_companies 3
# production_countries 3
# release_date 87
# revenue 6
# runtime 263
# spoken_languages 6
# status 87
# title 6
# vote_average 6
# vote_count 6

# %% [markdown]
# ---

# %% [markdown]
# Trabajo sobre las columnas anidadas, diccionarios y listas de diccionarios. (Decido quedarme con una columna de los mismos para observacion extrayendo solo el 'name' en cada caso y adjuntandolo al dataset aunque al momento no sea relevante para el estudio).

# %%
data['belongs_to_collection'].head()
# Out:
# 0    {'id': 10194, 'name': 'Toy Story Collection', ...
# 1                                                  NaN
# 2    {'id': 119050, 'name': 'Grumpy Old Men Collect...
# 3                                                  NaN
# 4    {'id': 96871, 'name': 'Father of the Bride Col...
# Name: belongs_to_collection, dtype: object

# %%
# Reemplazo el formato de comillas en la columna 'belongs_to_collection'
data['belongs_to_collection'] = data['belongs_to_collection'].replace("'", '"')
# Los convierto en string
data['belongs_to_collection'] = data['belongs_to_collection'].astype(str)
subdicc = dict()

# %%
# Creo una funcion para recorrer el df y extraer los datos de la columna 'belongs_to_collection' y lo almaceno en una nueva columna llamada 'franquicia'
for i in range(len(data)):
    franquicia = data.iloc[i]['belongs_to_collection']
    if pd.notna(franquicia):  
    
        try:
            subdicc = eval(franquicia)  # Uso 'eval' para convertir la cadena en un diccionario
            if isinstance(subdicc, dict):
                data.at[i, 'franquicia'] = subdicc.get('name')
            else:
                data.at[i, 'franquicia'] = None
        except:
            data.at[i, 'franquicia'] = None
    else:
        data.at[i, 'franquicia'] = None

data['franquicia']
# Out:
# 0                  Toy Story Collection
# 1                                  None
# 2             Grumpy Old Men Collection
# 3                                  None
# 4        Father of the Bride Collection
#                       ...
# 45461                              None
# 45462                              None
# 45463                              None
# 45464                              None
# 45465                              None
# Name: franquicia, Length: 45466, dtype: object

# %%
data.head(5)
# Out:
#                                belongs_to_collection    budget  \
# 0  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1                                                nan  65000000
# 2  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3                                                nan  16000000
# 4  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres     id original_language  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...    862                en
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...   8844                en
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...  15602                en
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...  31357                en
# 4                     [{'id': 35, 'name': 'Comedy'}]  11862                en
#
#                                             overview popularity  \
# 0  Led by Woody, Andy's toys live happily in his ...  21.946943
# 1  When siblings Judy and Peter discover an encha...  17.015539
# 2  A family wedding reignites the ancient feud be...    11.7129
# 3  Cheated on, mistreated and stepped on, the wom...   3.859495
# 4  Just when George Banks has recovered from his ...   8.387519
#
#                                 production_companies  \
# 0     [{'name': 'Pixar Animation Studios', 'id': 3}]
# 1  [{'name': 'TriStar Pictures', 'id': 559}, {'na...
# 2  [{'name': 'Warner Bros.', 'id': 6194}, {'name'...
# 3  [{'name': 'Twentieth Century Fox Film Corporat...
# 4  [{'name': 'Sandollar Productions', 'id': 5842}...
#
#                                 production_countries release_date  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-10-30
# 1  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-15
# 2  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22
# 3  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22
# 4  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-02-10
#
#        revenue  runtime                                   spoken_languages  \
# 0  373554033.0     81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1  262797249.0    104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2          0.0    101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3   81452156.0    127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4   76578911.0    106.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#      status                        title  vote_average  vote_count  \
# 0  Released                    Toy Story           7.7      5415.0
# 1  Released                      Jumanji           6.9      2413.0
# 2  Released             Grumpier Old Men           6.5        92.0
# 3  Released            Waiting to Exhale           6.1        34.0
# 4  Released  Father of the Bride Part II           5.7       173.0
#
#                        franquicia
# 0            Toy Story Collection
# 1                            None
# 2       Grumpy Old Men Collection
# 3                            None
# 4  Father of the Bride Collection

# %%
# Elimino la columna belongs_to_collection ya que no es relevante para el analisis.
data.drop(columns=['belongs_to_collection'],inplace=True)

# %%
data.head(5)
# Out:
#      budget                                             genres     id  \
# 0  30000000  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...    862
# 1  65000000  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...   8844
# 2         0  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...  15602
# 3  16000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...  31357
# 4         0                     [{'id': 35, 'name': 'Comedy'}]  11862
#
#   original_language                                           overview  \
# 0                en  Led by Woody, Andy's toys live happily in his ...
# 1                en  When siblings Judy and Peter discover an encha...
# 2                en  A family wedding reignites the ancient feud be...
# 3                en  Cheated on, mistreated and stepped on, the wom...
# 4                en  Just when George Banks has recovered from his ...
#
#   popularity                               production_companies  \
# 0  21.946943     [{'name': 'Pixar Animation Studios', 'id': 3}]
# 1  17.015539  [{'name': 'TriStar Pictures', 'id': 559}, {'na...
# 2    11.7129  [{'name': 'Warner Bros.', 'id': 6194}, {'name'...
# 3   3.859495  [{'name': 'Twentieth Century Fox Film Corporat...
# 4   8.387519  [{'name': 'Sandollar Productions', 'id': 5842}...
#
#                                 production_countries release_date  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-10-30
# 1  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-15
# 2  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22
# 3  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22
# 4  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-02-10
#
#        revenue  runtime                                   spoken_languages  \
# 0  373554033.0     81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1  262797249.0    104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2          0.0    101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3   81452156.0    127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4   76578911.0    106.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#      status                        title  vote_average  vote_count  \
# 0  Released                    Toy Story           7.7      5415.0
# 1  Released                      Jumanji           6.9      2413.0
# 2  Released             Grumpier Old Men           6.5        92.0
# 3  Released            Waiting to Exhale           6.1        34.0
# 4  Released  Father of the Bride Part II           5.7       173.0
#
#                        franquicia
# 0            Toy Story Collection
# 1                            None
# 2       Grumpy Old Men Collection
# 3                            None
# 4  Father of the Bride Collection

# %% [markdown]
# ---

# %% [markdown]
# Recorro cada fila de 'data' verificando que la columna a utilizar, 'production companies', contenga datos validos y los extraigo en una nueva columna a la cual le asigno el nombre 'productoras'
# *Utilizo Pandas para el manejo del DF y JSON para las cadenas.*

# %%
lista_productoras = []

for i in range(len(data)):
    lista_productoras = data.iloc[i]['production_companies']

    if pd.notna(lista_productoras):
    
    # Si es una cadena, intentar cargarla como JSON
        if isinstance(lista_productoras, str):
            try:
                lista_productoras = json.loads(lista_productoras.replace("'", "\""))
            except json.JSONDecodeError:
                lista_productoras = None
            
        if isinstance(lista_productoras, list):
            # Si es lista, procesar los diccionarios
            list_productora = []
            for valor in lista_productoras:
                if isinstance(valor, dict):
                    # si es un diccionario, obtener el nombre
                    productora_nombre = valor.get('name')
                    if productora_nombre:
                        list_productora.append(productora_nombre)
                elif isinstance(valor, str):
                    try:
                        # Si es una cadena JSON, cargarla como diccionario
                        diccionario = json.loads(valor.replace("'", "\""))
                        productora_nombre = diccionario.get('name')
                        if productora_nombre:
                            list_productora.append(productora_nombre)
                    except json.JSONDecodeError:
                        pass

            data.at[i, 'productoras'] = list_productora
        else:
            data.at[i, 'productoras'] = None
    else:
        data.at[i, 'productoras'] = None

# %%
# Creo una funcion para que elimine los corchetes de la lista.
def eliminar_corchetes(lista):
    if isinstance(lista, list):
        return ', '.join(lista)  # Se une los elementos de la lista con una coma y espacio
    return lista

# %%
data['productoras'] = data['productoras'].apply(eliminar_corchetes)

# %%
data['productoras']
# Out:
# 0                                  Pixar Animation Studios
# 1        TriStar Pictures, Teitler Film, Interscope Com...
# 2                             Warner Bros., Lancaster Gate
# 3                   Twentieth Century Fox Film Corporation
# 4               Sandollar Productions, Touchstone Pictures
#                                ...
# 45461
# 45462                                          Sine Olivia
# 45463                              American World Pictures
# 45464                                            Yermoliev
# 45465
# Name: productoras, Length: 45466, dtype: object

# %% [markdown]
# Recorro nuevamente cada fila de 'data' verificando que la columna a utilizar, 'production_countries', contenga datos validos y los extraigo en una nueva columna a la cual le asigno el nombre 'paises'.
# *Utilizo Pandas para el manejo del DF y JSON para las cadenas.*

# %%
lista_paises = []

for i in range(len(data)):
    lista_paises = data.iloc[i]['production_countries']

    if pd.notna(lista_paises):
    
        if isinstance(lista_paises, str):
            try:
                lista_paises = json.loads(lista_paises.replace("'", "\""))
            except json.JSONDecodeError:
                lista_paises = None
            
        if isinstance(lista_paises, list):
            paises = []
            for valor in lista_paises:
                if isinstance(valor, dict):
                    nombre = valor.get('name')
                    if nombre:
                        paises.append(nombre)
                elif isinstance(valor, str):
                    try:
                        diccionario = json.loads(valor.replace("'", "\""))
                        nombre = diccionario.get('name')
                        if nombre:
                            paises.append(nombre)
                    except json.JSONDecodeError:
                        pass

            data.at[i, 'paises'] = paises
        else:
            data.at[i, 'paises'] = None
    else:
        data.at[i, 'paises'] = None

# %%
# Aplico la funcion creada previamente para eliminar los corchetes de la lista.
data['paises'] = data['paises'].apply(eliminar_corchetes)

# %%
data['paises']
# Out:
# 0        United States of America
# 1        United States of America
# 2        United States of America
# 3        United States of America
# 4        United States of America
#                    ...
# 45461                        Iran
# 45462                 Philippines
# 45463    United States of America
# 45464                      Russia
# 45465              United Kingdom
# Name: paises, Length: 45466, dtype: object

# %%
data.head(2)
# Out:
#      budget                                             genres    id  \
# 0  30000000  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...   862
# 1  65000000  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...  8844
#
#   original_language                                           overview  \
# 0                en  Led by Woody, Andy's toys live happily in his ...
# 1                en  When siblings Judy and Peter discover an encha...
#
#   popularity                               production_companies  \
# 0  21.946943     [{'name': 'Pixar Animation Studios', 'id': 3}]
# 1  17.015539  [{'name': 'TriStar Pictures', 'id': 559}, {'na...
#
#                                 production_countries release_date  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-10-30
# 1  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-15
#
#        revenue  runtime                                   spoken_languages  \
# 0  373554033.0     81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1  262797249.0    104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
#
#      status      title  vote_average  vote_count            franquicia  \
# 0  Released  Toy Story           7.7      5415.0  Toy Story Collection
# 1  Released    Jumanji           6.9      2413.0                  None
#
#                                          productoras                    paises
# 0                            Pixar Animation Studios  United States of America
# 1  TriStar Pictures, Teitler Film, Interscope Com...  United States of America

# %% [markdown]
# Recorro nuevamente cada fila de 'data' verificando que la columna a utilizar, 'genres', contenga datos validos
# *Utilizo Pandas para el manejo del DF y JSON para las cadenas.*

# %%
if 'genres' not in data.columns:
    data['genres'] = None

for i in range(len(data)):
    lista_genero = data.iloc[i]['genres']

    if pd.notna(lista_genero):
        if isinstance(lista_genero, str):
            try:
                lista_genero = json.loads(lista_genero.replace("'", "\""))
            except json.JSONDecodeError:
                lista_genero = None

        if isinstance(lista_genero, list):
            generos = []
            for valor in lista_genero:
                if isinstance(valor, dict):
                    nombre = valor.get('name')
                    if nombre:
                        generos.append(nombre)
                elif isinstance(valor, str):
                    try:
                        diccionario = json.loads(valor.replace("'", "\""))
                        nombre = diccionario.get('name')
                        if nombre:
                            generos.append(nombre)
                    except json.JSONDecodeError:
                        pass

            data.at[i, 'genres'] = generos
        else:
            data.at[i, 'genres'] = None
    else:
        data.at[i, 'genres'] = None

# %%
data['genres'] = data['genres'].apply(eliminar_corchetes)

# %%
data['genres']
# Out:
# 0         Animation, Comedy, Family
# 1        Adventure, Fantasy, Family
# 2                   Romance, Comedy
# 3            Comedy, Drama, Romance
# 4                            Comedy
#                     ...
# 45461                 Drama, Family
# 45462                         Drama
# 45463       Action, Drama, Thriller
# 45464
# 45465
# Name: genres, Length: 45466, dtype: object

# %%
data.head(2)
# Out:
#      budget                      genres    id original_language  \
# 0  30000000   Animation, Comedy, Family   862                en
# 1  65000000  Adventure, Fantasy, Family  8844                en
#
#                                             overview popularity  \
# 0  Led by Woody, Andy's toys live happily in his ...  21.946943
# 1  When siblings Judy and Peter discover an encha...  17.015539
#
#                                 production_companies  \
# 0     [{'name': 'Pixar Animation Studios', 'id': 3}]
# 1  [{'name': 'TriStar Pictures', 'id': 559}, {'na...
#
#                                 production_countries release_date  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-10-30
# 1  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-15
#
#        revenue  runtime                                   spoken_languages  \
# 0  373554033.0     81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1  262797249.0    104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
#
#      status      title  vote_average  vote_count            franquicia  \
# 0  Released  Toy Story           7.7      5415.0  Toy Story Collection
# 1  Released    Jumanji           6.9      2413.0                  None
#
#                                          productoras                    paises
# 0                            Pixar Animation Studios  United States of America
# 1  TriStar Pictures, Teitler Film, Interscope Com...  United States of America

# %%
# Elimino las columas 'production_companies' y 'production_countries' ya que no son relevantes para el analisis.
data.drop(columns=['production_companies', 'production_countries'], inplace=True)

# %%
data.head(2)
# Out:
#      budget                      genres    id original_language  \
# 0  30000000   Animation, Comedy, Family   862                en
# 1  65000000  Adventure, Fantasy, Family  8844                en
#
#                                             overview popularity release_date  \
# 0  Led by Woody, Andy's toys live happily in his ...  21.946943   1995-10-30
# 1  When siblings Judy and Peter discover an encha...  17.015539   1995-12-15
#
#        revenue  runtime                                   spoken_languages  \
# 0  373554033.0     81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1  262797249.0    104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
#
#      status      title  vote_average  vote_count            franquicia  \
# 0  Released  Toy Story           7.7      5415.0  Toy Story Collection
# 1  Released    Jumanji           6.9      2413.0                  None
#
#                                          productoras                    paises
# 0                            Pixar Animation Studios  United States of America
# 1  TriStar Pictures, Teitler Film, Interscope Com...  United States of America

# %% [markdown]
# --------------------

# %% [markdown]
# Tratamiento de valores nulos de la columna 'original_languages'.

# %%
# Visualizo la columna 'original_languages' que sera necesaria para las consultas en la API.
data['original_language'].isna().sum()
# Out:
# 11

# %%
# trato los valores nulos en la columna 'original_language' con el valor 'unknown' para no eliminar la fila completa.
data = data.assign(original_language=data['original_language'].fillna('unknown'))

# %%
# Corroboro que se haya aplicado el reemplazo.
data['original_language'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ---

# %% [markdown]
# Verifico el tipo de dato de 'runtime' y 'release_date' para utilizarlos luego en la API, normalizo el tipo de datos para ser consumidos por la misma.

# %%
data['runtime'].head(3)
# Out:
# 0     81.0
# 1    104.0
# 2    101.0
# Name: runtime, dtype: float64

# %%
# Relleno los valores nulos en la columna 'runtime' con 0
data['runtime'] = data['runtime'].fillna(0)

# %%
# Decido cambiar el tipo de dato de la columna 'runtime' de float a int, quedando en minutos.
data['runtime'] = data['runtime'].astype(int)

# %%
data['runtime'].head()
# Out:
# 0     81
# 1    104
# 2    101
# 3    127
# 4    106
# Name: runtime, dtype: int32

# %% [markdown]
# Trabajo ahora con 'release_date'. Normalizo los datos y creo una nueva columna llamada 'release_year'.

# %%
# Convierto 'release_date' a formato datetime con Pandas, errors='coerce' para que los valores que no se puedan convertir a datetime se conviertan en NaN y no generen un error
data['release_date'] = pd.to_datetime(data['release_date'], errors='coerce')

# %%
#Elimino las filas de 'release_date' que tengan valores NaN
data.dropna(subset=['release_date'], inplace=True)
#Inserto una nueva columna llamada 'release_year' en el dataframe luego de release_date y luego asigno los valores correspondientes a la nueva columna
data.insert(data.columns.get_loc('release_date') + 1, 'release_year', None)
data['release_year'] = data['release_date'].dt.year

# %%
data.insert(data.columns.get_loc('release_date') + 2, 'release_month', None)
data['release_month'] = data['release_date'].dt.month

# %%
# Obtenengo el nombre del día de la semana en inglés
data['day_of_week'] = data['release_date'].dt.day_name()

#Creo un Diccionario para traducir los días de la semana al español
dias_semana = {
    'Monday': 'Lunes',
    'Tuesday': 'Martes',
    'Wednesday': 'Miércoles',
    'Thursday': 'Jueves',
    'Friday': 'Viernes',
    'Saturday': 'Sábado',
    'Sunday': 'Domingo'
}
#Traducir los días de la semana al español
data['day_of_week'] = data['day_of_week'].map(dias_semana)

data.head(3)
# Out:
#      budget                      genres     id original_language  \
# 0  30000000   Animation, Comedy, Family    862                en
# 1  65000000  Adventure, Fantasy, Family   8844                en
# 2         0             Romance, Comedy  15602                en
#
#                                             overview popularity release_date  \
# 0  Led by Woody, Andy's toys live happily in his ...  21.946943   1995-10-30
# 1  When siblings Judy and Peter discover an encha...  17.015539   1995-12-15
# 2  A family wedding reignites the ancient feud be...    11.7129   1995-12-22
#
#    release_year  release_month      revenue  runtime  \
# 0          1995             10  373554033.0       81
# 1          1995             12  262797249.0      104
# 2          1995             12          0.0      101
#
#                                     spoken_languages    status  \
# 0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 2           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#               title  vote_average  vote_count                 franquicia  \
# 0         Toy Story           7.7      5415.0       Toy Story Collection
# 1           Jumanji           6.9      2413.0                       None
# 2  Grumpier Old Men           6.5        92.0  Grumpy Old Men Collection
#
#                                          productoras  \
# 0                            Pixar Animation Studios
# 1  TriStar Pictures, Teitler Film, Interscope Com...
# 2                       Warner Bros., Lancaster Gate
#
#                      paises day_of_week
# 0  United States of America       Lunes
# 1  United States of America     Viernes
# 2  United States of America     Viernes

# %%
# Creo una funcion listOfColumns que recorra las columnas ingresadas y reemplace los valores NaN por 0
def replace_to_cero(listOfColumns: list[str]):
    for col in listOfColumns:
        data[col] = data[col].fillna(0)

listOfColumns = ['id','budget','revenue','runtime','popularity','vote_average','vote_count']
replace_to_cero(listOfColumns)

# %%
data.head(2)
# Out:
#      budget                      genres    id original_language  \
# 0  30000000   Animation, Comedy, Family   862                en
# 1  65000000  Adventure, Fantasy, Family  8844                en
#
#                                             overview popularity release_date  \
# 0  Led by Woody, Andy's toys live happily in his ...  21.946943   1995-10-30
# 1  When siblings Judy and Peter discover an encha...  17.015539   1995-12-15
#
#    release_year  release_month      revenue  runtime  \
# 0          1995             10  373554033.0       81
# 1          1995             12  262797249.0      104
#
#                                     spoken_languages    status      title  \
# 0           [{'iso_639_1': 'en', 'name': 'English'}]  Released  Toy Story
# 1  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released    Jumanji
#
#    vote_average  vote_count            franquicia  \
# 0           7.7      5415.0  Toy Story Collection
# 1           6.9      2413.0                  None
#
#                                          productoras  \
# 0                            Pixar Animation Studios
# 1  TriStar Pictures, Teitler Film, Interscope Com...
#
#                      paises day_of_week
# 0  United States of America       Lunes
# 1  United States of America     Viernes

# %% [markdown]
# ----

# %% [markdown]
# Trabajo con las columnas 'revenue' y 'budget', normalizo los datos, y realizo la operacion para calcular el retorno ('return') de inversion creando una nueva columna,'return'.

# %%
# Transformo ambas columnas a numerico.
data['revenue'] = pd.to_numeric(data['revenue'], errors='coerce')
data['budget'] = pd.to_numeric(data['budget'], errors='coerce')

# Creo una nueva columna 'return' que contenga el resultado de la división de 'revenue' y 'budget'.
data['return'] = data['revenue'] / data['budget']

# %%
# Solicito que me muestre la columna creada, observo valores NaN e infinitos por lo que trabajare con la columna 'return' para normalizarlo.
data['return'].head(5)
# Out:
# 0    12.451801
# 1     4.043035
# 2          NaN
# 3     5.090760
# 4          inf
# Name: return, dtype: float64

# %%
data.replace({'return': {float('inf'): 0}}, inplace=True)

# %%
#Utilizo la funcion creada en la columna 'return' para reemplazar los valores NaN por 0
replace_to_cero(['return'])

# %%
data['return'].head()
# Out:
# 0    12.451801
# 1     4.043035
# 2     0.000000
# 3     5.090760
# 4     0.000000
# Name: return, dtype: float64

# %%
#Redondeo los valores de la columna 'return' a 2 decimales
data['return'] = data['return'].apply(lambda x: round(x, 2))

# %%
data['return'].head(5)
# Out:
# 0    12.45
# 1     4.04
# 2     0.00
# 3     5.09
# 4     0.00
# Name: return, dtype: float64

# %%
data.drop(columns=['release_date'],inplace=True)

# %%
# grabo el dataset limpio en un archivo csv en la carpeta Datasets_limpios
data.to_csv('../Datasets_limpios/movies_dataset_clean.csv', index=False)

# %%
data.head(3)
# Out:
#      budget                      genres     id original_language  \
# 0  30000000   Animation, Comedy, Family    862                en
# 1  65000000  Adventure, Fantasy, Family   8844                en
# 2         0             Romance, Comedy  15602                en
#
#                                             overview popularity  release_year  \
# 0  Led by Woody, Andy's toys live happily in his ...  21.946943          1995
# 1  When siblings Judy and Peter discover an encha...  17.015539          1995
# 2  A family wedding reignites the ancient feud be...    11.7129          1995
#
#    release_month      revenue  runtime  \
# 0             10  373554033.0       81
# 1             12  262797249.0      104
# 2             12          0.0      101
#
#                                     spoken_languages    status  \
# 0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 2           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#               title  vote_average  vote_count                 franquicia  \
# 0         Toy Story           7.7      5415.0       Toy Story Collection
# 1           Jumanji           6.9      2413.0                       None
# 2  Grumpier Old Men           6.5        92.0  Grumpy Old Men Collection
#
#                                          productoras  \
# 0                            Pixar Animation Studios
# 1  TriStar Pictures, Teitler Film, Interscope Com...
# 2                       Warner Bros., Lancaster Gate
#
#                      paises day_of_week  return
# 0  United States of America       Lunes   12.45
# 1  United States of America     Viernes    4.04
# 2  United States of America     Viernes    0.00
